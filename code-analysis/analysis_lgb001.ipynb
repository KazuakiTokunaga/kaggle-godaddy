# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

import lightgbm as lgb
import optuna

SMAPE_ENABLED = True
LAGS = [1, 2, 3, 4, 5, 6, 7, 8]
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def to_percent(X, y):
    yhat = (X['lags(1)'] - y) / X['lags(1)']
    yhat[X['lags(1)'] == 0] = 0 # denominator cannot be 0
    return yhat

def from_percent(X, y):
    yhat = X['lags(1)'] - (y * X[f'lags(1)'])
    return yhat

def smape(y_true, y_pred):
    smap = np.zeros(len(y_true))
    
    num = np.abs(y_true - y_pred)
    dem = ((np.abs(y_true) + np.abs(y_pred)) / 2)
    
    pos_ind = (y_true != 0) | (y_pred != 0)
    smap[pos_ind] = num[pos_ind] / dem[pos_ind]
    
    return 100 * np.mean(smap)

def lgb_objective(trial):
    params = {
        'n_iter'           : 200,
        'verbosity'        : -1,
        'objective'        : 'l1',
        'random_state'     : 42,
        'extra_trees'      : True,
        'colsample_bytree' : trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'colsample_bynode' : trial.suggest_float('colsample_bynode', 0.1, 1.0),
        'max_depth'        : trial.suggest_int('max_depth', 3, 10),
        'learning_rate'    : trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'lambda_l1'        : trial.suggest_float('lambda_l1', 1e-2, 10.0),
        'lambda_l2'        : trial.suggest_float('lambda_l2', 1e-2, 10.0),
        'num_leaves'       : trial.suggest_int('num_leaves', 8, 1024),
        'min_data_in_leaf' : trial.suggest_int('min_data_in_leaf', 5, 250),}
    
    model  = lgb.LGBMRegressor(**params)
    X, y   = df_all.drop(columns=[target]), df_all[target]
    
    train_times = list(range(38))
    valid_times = [38]
    
    y_train = y[X['scale'].isin(train_times)]
    y_valid = y[X['scale'].isin(valid_times)]
    
    X_train = X[X['scale'].isin(train_times)]
    X_valid = X[X['scale'].isin(valid_times)]
    
    if SMAPE_ENABLED:
        y_train = to_percent(X_train, y_train)
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    
    if SMAPE_ENABLED:
        y_pred = from_percent(X_valid, y_pred)
    
    return smape(y_valid, y_pred)

# %%
BASE = '../input/'
date_col = 'first_day_of_month'
cat_cols = ['county', 'state']
target = 'microbusiness_density'
idx = 'row_id'

# %%
df_census = pd.read_csv(BASE + 'census_starter.csv', index_col='cfips')
df_train = pd.read_csv(BASE + 'train.csv',  index_col=idx)
df_test = pd.read_csv(BASE + 'test.csv',  index_col=idx)
df_subm = pd.read_csv(BASE + 'sample_submission.csv',  index_col=idx)

# %%
state_dict = df_train[['cfips', 'state', 'county']]
state_dict = state_dict.set_index('cfips')
state_dict = state_dict.drop_duplicates()
state_dict = state_dict.to_dict()

df_test['state'] = df_test['cfips'].map(state_dict['state'])
df_test['county'] = df_test['cfips'].map(state_dict['county'])

df_all = pd.concat([df_train, df_test], axis=0)

df_all[date_col] = pd.to_datetime(df_all[date_col])

df_all['year'] = df_all[date_col].dt.year
df_all['month'] = df_all[date_col].dt.month
df_all['scale'] = (df_all[date_col] - df_all[date_col].min()).dt.days
df_all['scale'] = df_all['scale'].factorize()[0]

# %%
for i in LAGS:
    df_all[f'lags({i})'] = df_all.groupby('cfips')[target].shift(i)
    
df_all['active'] = df_all.groupby('cfips')['active'].shift(8)

# %%
df_all = df_all.drop(columns=[date_col])
df_all[cat_cols] = df_all[cat_cols].astype('category')

df_all = df_all.reset_index()
df_all = df_all.set_index('cfips')

df_all[df_census.columns] = df_census

df_all = df_all.reset_index()
df_all = df_all.set_index(idx)

# %%
df_all = df_all[df_all['scale'] != 0]

# %%
study = optuna.create_study(direction='minimize', study_name='Regressor')
study.optimize(lgb_objective, n_trials=30, show_progress_bar=True)
# Out:
# [I 2023-01-31 12:29:07,170] A new study created in memory with name: Regressor
#   0%|          | 0/30 [00:00<?, ?it/s]
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:177: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] lambda_l1 is set=6.147756675365701, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.147756675365701
# [LightGBM] [Warning] lambda_l2 is set=9.775103002414689, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.775103002414689
# [LightGBM] [Warning] min_data_in_leaf is set=158, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=158
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:31:32,668] Trial 0 finished with value: 1.0700032817911214 and parameters: {'colsample_bytree': 0.9811096308258251, 'colsample_bynode': 0.5681824208096472, 'max_depth': 6, 'learning_rate': 0.06594559584194976, 'lambda_l1': 6.147756675365701, 'lambda_l2': 9.775103002414689, 'num_leaves': 361, 'min_data_in_leaf': 158}. Best is trial 0 with value: 1.0700032817911214.
# [LightGBM] [Warning] lambda_l1 is set=0.9783211029540011, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.9783211029540011
# [LightGBM] [Warning] lambda_l2 is set=9.922666085742053, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.922666085742053
# [LightGBM] [Warning] min_data_in_leaf is set=160, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=160
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:34:48,068] Trial 1 finished with value: 1.0720098413751513 and parameters: {'colsample_bytree': 0.7881175164053723, 'colsample_bynode': 0.6060340368861783, 'max_depth': 5, 'learning_rate': 0.09786614129578035, 'lambda_l1': 0.9783211029540011, 'lambda_l2': 9.922666085742053, 'num_leaves': 22, 'min_data_in_leaf': 160}. Best is trial 0 with value: 1.0700032817911214.
# [LightGBM] [Warning] lambda_l1 is set=6.1160444152768125, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.1160444152768125
# [LightGBM] [Warning] lambda_l2 is set=1.6043715624275774, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.6043715624275774
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:36:33,338] Trial 2 finished with value: 1.0732000258447734 and parameters: {'colsample_bytree': 0.6749796339773719, 'colsample_bynode': 0.11545600139968382, 'max_depth': 6, 'learning_rate': 0.08806045241304827, 'lambda_l1': 6.1160444152768125, 'lambda_l2': 1.6043715624275774, 'num_leaves': 528, 'min_data_in_leaf': 65}. Best is trial 0 with value: 1.0700032817911214.
# [LightGBM] [Warning] lambda_l1 is set=4.5361547671135645, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.5361547671135645
# [LightGBM] [Warning] lambda_l2 is set=5.445829397542219, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.445829397542219
# [LightGBM] [Warning] min_data_in_leaf is set=238, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=238
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:37:48,028] Trial 3 finished with value: 1.071795098958696 and parameters: {'colsample_bytree': 0.4741155629164626, 'colsample_bynode': 0.14687515929556838, 'max_depth': 8, 'learning_rate': 0.0740950222256222, 'lambda_l1': 4.5361547671135645, 'lambda_l2': 5.445829397542219, 'num_leaves': 996, 'min_data_in_leaf': 238}. Best is trial 0 with value: 1.0700032817911214.
# [LightGBM] [Warning] lambda_l1 is set=0.21363138408954224, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.21363138408954224
# [LightGBM] [Warning] lambda_l2 is set=7.032415494999585, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.032415494999585
# [LightGBM] [Warning] min_data_in_leaf is set=231, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=231
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:15,553] Trial 4 finished with value: 1.0710207809473309 and parameters: {'colsample_bytree': 0.564337915008849, 'colsample_bynode': 0.9824284833124622, 'max_depth': 9, 'learning_rate': 0.03239105035728978, 'lambda_l1': 0.21363138408954224, 'lambda_l2': 7.032415494999585, 'num_leaves': 522, 'min_data_in_leaf': 231}. Best is trial 0 with value: 1.0700032817911214.
# [LightGBM] [Warning] lambda_l1 is set=9.197543928109797, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.197543928109797
# [LightGBM] [Warning] lambda_l2 is set=2.1404172763704765, reg_lambda=0.0 will be ignored. Current value: lambda_l2=2.1404172763704765
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:26,110] Trial 5 finished with value: 1.0710276155890768 and parameters: {'colsample_bytree': 0.7552558962990703, 'colsample_bynode': 0.5525069435021884, 'max_depth': 6, 'learning_rate': 0.03991719651108368, 'lambda_l1': 9.197543928109797, 'lambda_l2': 2.1404172763704765, 'num_leaves': 311, 'min_data_in_leaf': 38}. Best is trial 0 with value: 1.0700032817911214.
# [LightGBM] [Warning] lambda_l1 is set=5.304975287049087, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.304975287049087
# [LightGBM] [Warning] lambda_l2 is set=6.98249539780767, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.98249539780767
# [LightGBM] [Warning] min_data_in_leaf is set=148, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=148
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:33,361] Trial 6 finished with value: 1.0699579531126844 and parameters: {'colsample_bytree': 0.3742691819954934, 'colsample_bynode': 0.9819839633147851, 'max_depth': 7, 'learning_rate': 0.08688436188422485, 'lambda_l1': 5.304975287049087, 'lambda_l2': 6.98249539780767, 'num_leaves': 824, 'min_data_in_leaf': 148}. Best is trial 6 with value: 1.0699579531126844.
# [LightGBM] [Warning] lambda_l1 is set=9.048249139369274, reg_alpha=0.0 will be ignored. Current value: lambda_l1=9.048249139369274
# [LightGBM] [Warning] lambda_l2 is set=5.866384570386251, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.866384570386251
# [LightGBM] [Warning] min_data_in_leaf is set=168, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=168
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:39,066] Trial 7 finished with value: 1.0741317576779337 and parameters: {'colsample_bytree': 0.21650751734994927, 'colsample_bynode': 0.34259894304606375, 'max_depth': 8, 'learning_rate': 0.037367248434093406, 'lambda_l1': 9.048249139369274, 'lambda_l2': 5.866384570386251, 'num_leaves': 145, 'min_data_in_leaf': 168}. Best is trial 6 with value: 1.0699579531126844.
# [LightGBM] [Warning] lambda_l1 is set=4.018288975189629, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.018288975189629
# [LightGBM] [Warning] lambda_l2 is set=7.146232780701737, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.146232780701737
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:43,692] Trial 8 finished with value: 1.0881699779072243 and parameters: {'colsample_bytree': 0.11761957311344902, 'colsample_bynode': 0.1356911069424349, 'max_depth': 6, 'learning_rate': 0.010221997608230723, 'lambda_l1': 4.018288975189629, 'lambda_l2': 7.146232780701737, 'num_leaves': 733, 'min_data_in_leaf': 43}. Best is trial 6 with value: 1.0699579531126844.
# [LightGBM] [Warning] lambda_l1 is set=4.021090296161261, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.021090296161261
# [LightGBM] [Warning] lambda_l2 is set=0.8888700387132186, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.8888700387132186
# [LightGBM] [Warning] min_data_in_leaf is set=209, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=209
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:51,165] Trial 9 finished with value: 1.0733360900758453 and parameters: {'colsample_bytree': 0.5201047339933245, 'colsample_bynode': 0.7286925631078145, 'max_depth': 3, 'learning_rate': 0.07763868616300061, 'lambda_l1': 4.021090296161261, 'lambda_l2': 0.8888700387132186, 'num_leaves': 561, 'min_data_in_leaf': 209}. Best is trial 6 with value: 1.0699579531126844.
# [LightGBM] [Warning] lambda_l1 is set=7.409543399375718, reg_alpha=0.0 will be ignored. Current value: lambda_l1=7.409543399375718
# [LightGBM] [Warning] lambda_l2 is set=3.7566001982298483, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.7566001982298483
# [LightGBM] [Warning] min_data_in_leaf is set=98, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=98
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:38:59,629] Trial 10 finished with value: 1.0744633975241342 and parameters: {'colsample_bytree': 0.3525135661188991, 'colsample_bynode': 0.9461369410323662, 'max_depth': 10, 'learning_rate': 0.015714976057187198, 'lambda_l1': 7.409543399375718, 'lambda_l2': 3.7566001982298483, 'num_leaves': 1001, 'min_data_in_leaf': 98}. Best is trial 6 with value: 1.0699579531126844.
# [LightGBM] [Warning] lambda_l1 is set=6.568733032092776, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.568733032092776
# [LightGBM] [Warning] lambda_l2 is set=9.849251679487372, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.849251679487372
# [LightGBM] [Warning] min_data_in_leaf is set=131, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=131
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:39:09,860] Trial 11 finished with value: 1.0731272892703003 and parameters: {'colsample_bytree': 0.9986425716087616, 'colsample_bynode': 0.8063860314751822, 'max_depth': 3, 'learning_rate': 0.056124571809771186, 'lambda_l1': 6.568733032092776, 'lambda_l2': 9.849251679487372, 'num_leaves': 721, 'min_data_in_leaf': 131}. Best is trial 6 with value: 1.0699579531126844.
# [LightGBM] [Warning] lambda_l1 is set=2.6084923220769833, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.6084923220769833
# [LightGBM] [Warning] lambda_l2 is set=8.39266221310978, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.39266221310978
# [LightGBM] [Warning] min_data_in_leaf is set=182, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=182
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:39:22,907] Trial 12 finished with value: 1.0687445428538411 and parameters: {'colsample_bytree': 0.8914072108536055, 'colsample_bynode': 0.37392209490917633, 'max_depth': 7, 'learning_rate': 0.05739535082694759, 'lambda_l1': 2.6084923220769833, 'lambda_l2': 8.39266221310978, 'num_leaves': 313, 'min_data_in_leaf': 182}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=2.2871824888824386, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.2871824888824386
# [LightGBM] [Warning] lambda_l2 is set=7.917971142336293, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.917971142336293
# [LightGBM] [Warning] min_data_in_leaf is set=191, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=191
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:39:30,456] Trial 13 finished with value: 1.072381765340873 and parameters: {'colsample_bytree': 0.3498832215270882, 'colsample_bynode': 0.364269214744375, 'max_depth': 8, 'learning_rate': 0.05084981431065219, 'lambda_l1': 2.2871824888824386, 'lambda_l2': 7.917971142336293, 'num_leaves': 799, 'min_data_in_leaf': 191}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=2.4845732507187726, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4845732507187726
# [LightGBM] [Warning] lambda_l2 is set=8.217453561093253, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.217453561093253
# [LightGBM] [Warning] min_data_in_leaf is set=113, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=113
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:39:43,297] Trial 14 finished with value: 1.070246372290105 and parameters: {'colsample_bytree': 0.8572310669918859, 'colsample_bynode': 0.36915148505687745, 'max_depth': 7, 'learning_rate': 0.02018809909065742, 'lambda_l1': 2.4845732507187726, 'lambda_l2': 8.217453561093253, 'num_leaves': 342, 'min_data_in_leaf': 113}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=2.578499780255376, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.578499780255376
# [LightGBM] [Warning] lambda_l2 is set=3.9590114041667257, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.9590114041667257
# [LightGBM] [Warning] min_data_in_leaf is set=93, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=93
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:39:49,754] Trial 15 finished with value: 1.071730184105521 and parameters: {'colsample_bytree': 0.37316045074657567, 'colsample_bynode': 0.2818870145029662, 'max_depth': 4, 'learning_rate': 0.04966234842611283, 'lambda_l1': 2.578499780255376, 'lambda_l2': 3.9590114041667257, 'num_leaves': 873, 'min_data_in_leaf': 93}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=5.378278962580319, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.378278962580319
# [LightGBM] [Warning] lambda_l2 is set=8.49135371480125, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.49135371480125
# [LightGBM] [Warning] min_data_in_leaf is set=136, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=136
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:39:59,504] Trial 16 finished with value: 1.0733853379507685 and parameters: {'colsample_bytree': 0.6203341503509479, 'colsample_bynode': 0.7360617715300344, 'max_depth': 7, 'learning_rate': 0.09937066725908722, 'lambda_l1': 5.378278962580319, 'lambda_l2': 8.49135371480125, 'num_leaves': 210, 'min_data_in_leaf': 136}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=3.429060814570451, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.429060814570451
# [LightGBM] [Warning] lambda_l2 is set=6.32327079492198, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.32327079492198
# [LightGBM] [Warning] min_data_in_leaf is set=198, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=198
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:08,347] Trial 17 finished with value: 1.071434331255718 and parameters: {'colsample_bytree': 0.4424664511950047, 'colsample_bynode': 0.46225478615366816, 'max_depth': 10, 'learning_rate': 0.026694835351556083, 'lambda_l1': 3.429060814570451, 'lambda_l2': 6.32327079492198, 'num_leaves': 672, 'min_data_in_leaf': 198}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=1.2745235892924667, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.2745235892924667
# [LightGBM] [Warning] lambda_l2 is set=4.5653792235290345, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.5653792235290345
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:14,318] Trial 18 finished with value: 1.069189489160422 and parameters: {'colsample_bytree': 0.21840339715815144, 'colsample_bynode': 0.8264636589092389, 'max_depth': 5, 'learning_rate': 0.05713860754201785, 'lambda_l1': 1.2745235892924667, 'lambda_l2': 4.5653792235290345, 'num_leaves': 429, 'min_data_in_leaf': 6}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=1.3464944808426305, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.3464944808426305
# [LightGBM] [Warning] lambda_l2 is set=4.3781804401522955, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.3781804401522955
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:20,294] Trial 19 finished with value: 1.0706343346651814 and parameters: {'colsample_bytree': 0.2197756780033366, 'colsample_bynode': 0.856886446841294, 'max_depth': 5, 'learning_rate': 0.06047403159604191, 'lambda_l1': 1.3464944808426305, 'lambda_l2': 4.3781804401522955, 'num_leaves': 420, 'min_data_in_leaf': 5}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=0.06303518571283862, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06303518571283862
# [LightGBM] [Warning] lambda_l2 is set=4.877411903213675, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.877411903213675
# [LightGBM] [Warning] min_data_in_leaf is set=69, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=69
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:30,641] Trial 20 finished with value: 1.0700237510563209 and parameters: {'colsample_bytree': 0.8550425015649755, 'colsample_bynode': 0.6767094400641329, 'max_depth': 4, 'learning_rate': 0.046202225554687906, 'lambda_l1': 0.06303518571283862, 'lambda_l2': 4.877411903213675, 'num_leaves': 195, 'min_data_in_leaf': 69}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=1.789383236345882, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.789383236345882
# [LightGBM] [Warning] lambda_l2 is set=3.410316240974742, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.410316240974742
# [LightGBM] [Warning] min_data_in_leaf is set=179, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=179
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:36,984] Trial 21 finished with value: 1.0722010024378938 and parameters: {'colsample_bytree': 0.2470733320771698, 'colsample_bynode': 0.8946465386109335, 'max_depth': 7, 'learning_rate': 0.06966723347514418, 'lambda_l1': 1.789383236345882, 'lambda_l2': 3.410316240974742, 'num_leaves': 628, 'min_data_in_leaf': 179}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=3.225221110761383, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.225221110761383
# [LightGBM] [Warning] lambda_l2 is set=6.987346031810514, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.987346031810514
# [LightGBM] [Warning] min_data_in_leaf is set=148, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=148
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:41,813] Trial 22 finished with value: 1.0774715432097672 and parameters: {'colsample_bytree': 0.1272173426538074, 'colsample_bynode': 0.988580275602848, 'max_depth': 5, 'learning_rate': 0.08053741413358366, 'lambda_l1': 3.225221110761383, 'lambda_l2': 6.987346031810514, 'num_leaves': 410, 'min_data_in_leaf': 148}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=5.151653148381598, reg_alpha=0.0 will be ignored. Current value: lambda_l1=5.151653148381598
# [LightGBM] [Warning] lambda_l2 is set=8.605321343515453, reg_lambda=0.0 will be ignored. Current value: lambda_l2=8.605321343515453
# [LightGBM] [Warning] min_data_in_leaf is set=214, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=214
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:48,823] Trial 23 finished with value: 1.0723194786631969 and parameters: {'colsample_bytree': 0.29610230625881107, 'colsample_bynode': 0.4782522429310839, 'max_depth': 9, 'learning_rate': 0.04225529897258837, 'lambda_l1': 5.151653148381598, 'lambda_l2': 8.605321343515453, 'num_leaves': 442, 'min_data_in_leaf': 214}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=8.150306407672677, reg_alpha=0.0 will be ignored. Current value: lambda_l1=8.150306407672677
# [LightGBM] [Warning] lambda_l2 is set=3.0309903491424093, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.0309903491424093
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:40:59,319] Trial 24 finished with value: 1.0707698272252306 and parameters: {'colsample_bytree': 0.41372641139231414, 'colsample_bynode': 0.817768266704743, 'max_depth': 7, 'learning_rate': 0.02925310304136247, 'lambda_l1': 8.150306407672677, 'lambda_l2': 3.0309903491424093, 'num_leaves': 279, 'min_data_in_leaf': 5}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=1.315698288782459, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.315698288782459
# [LightGBM] [Warning] lambda_l2 is set=5.98288882431293, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.98288882431293
# [LightGBM] [Warning] min_data_in_leaf is set=116, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=116
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:41:05,796] Trial 25 finished with value: 1.0742191156516308 and parameters: {'colsample_bytree': 0.28598490669593335, 'colsample_bynode': 0.2290970161408827, 'max_depth': 4, 'learning_rate': 0.058819471477087125, 'lambda_l1': 1.315698288782459, 'lambda_l2': 5.98288882431293, 'num_leaves': 876, 'min_data_in_leaf': 116}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=3.1041523688296744, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.1041523688296744
# [LightGBM] [Warning] lambda_l2 is set=4.950992935924111, reg_lambda=0.0 will be ignored. Current value: lambda_l2=4.950992935924111
# [LightGBM] [Warning] min_data_in_leaf is set=176, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=176
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:41:11,491] Trial 26 finished with value: 1.072329261734961 and parameters: {'colsample_bytree': 0.17928772816160266, 'colsample_bynode': 0.44324358948713, 'max_depth': 5, 'learning_rate': 0.06585175133616157, 'lambda_l1': 3.1041523688296744, 'lambda_l2': 4.950992935924111, 'num_leaves': 596, 'min_data_in_leaf': 176}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=4.380405804282248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=4.380405804282248
# [LightGBM] [Warning] lambda_l2 is set=9.043703343439674, reg_lambda=0.0 will be ignored. Current value: lambda_l2=9.043703343439674
# [LightGBM] [Warning] min_data_in_leaf is set=146, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=146
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:41:23,044] Trial 27 finished with value: 1.073465643162705 and parameters: {'colsample_bytree': 0.6685125850574188, 'colsample_bynode': 0.9150442557872247, 'max_depth': 8, 'learning_rate': 0.022977213363816005, 'lambda_l1': 4.380405804282248, 'lambda_l2': 9.043703343439674, 'num_leaves': 463, 'min_data_in_leaf': 146}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=0.7556649037948184, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.7556649037948184
# [LightGBM] [Warning] lambda_l2 is set=7.605980190378571, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.605980190378571
# [LightGBM] [Warning] min_data_in_leaf is set=80, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=80
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:41:39,330] Trial 28 finished with value: 1.0703026627251397 and parameters: {'colsample_bytree': 0.5153010954733311, 'colsample_bynode': 0.6574987003981061, 'max_depth': 9, 'learning_rate': 0.03468472871399092, 'lambda_l1': 0.7556649037948184, 'lambda_l2': 7.605980190378571, 'num_leaves': 233, 'min_data_in_leaf': 80}. Best is trial 12 with value: 1.0687445428538411.
# [LightGBM] [Warning] lambda_l1 is set=6.372539752351248, reg_alpha=0.0 will be ignored. Current value: lambda_l1=6.372539752351248
# [LightGBM] [Warning] lambda_l2 is set=6.484989974416297, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.484989974416297
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [I 2023-01-31 12:41:51,403] Trial 29 finished with value: 1.0767145567402612 and parameters: {'colsample_bytree': 0.9166382633419011, 'colsample_bynode': 0.7774397687107211, 'max_depth': 6, 'learning_rate': 0.08441665836019674, 'lambda_l1': 6.372539752351248, 'lambda_l2': 6.484989974416297, 'num_leaves': 106, 'min_data_in_leaf': 33}. Best is trial 12 with value: 1.0687445428538411.

# %%
params = {
    'n_iter': 200,
    'verbosity': -1,
    'objective': 'l1',
    'random_state': 42,
    'extra_trees': True,
    'colsample_bytree': 0.8841279649367693,
    'colsample_bynode': 0.10142964450634374,
    'max_depth': 8,
    'learning_rate': 0.013647749926797374,
    'lambda_l1': 1.8386216853616875,
    'lambda_l2': 7.557660410418351,
    'num_leaves': 61,
    'min_data_in_leaf': 213}

model = lgb.LGBMRegressor(**params)

# %%
X, y   = df_all.drop(columns=[target]), df_all[target]
X_test, y_test = X[y.isnull()], y[y.isnull()]

train_times = list(range(38))

X_train = X[X['scale'].isin(train_times)]
y_train = y[X['scale'].isin(train_times)]

if SMAPE_ENABLED:
    y_train = to_percent(X_train, y_train)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

if SMAPE_ENABLED:
    y_pred = from_percent(X_test, y_pred)
    
df_subm.loc[y_pred.index, target] = y_pred
# Out:
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200

# %%
X, y   = df_all.drop(columns=[target]), df_all[target]
valid_times = list(range(31, 39))
results = []

for valid_time in valid_times:
    train_times = list(range(valid_time))
    
    X_train = X[X['scale'].isin(train_times)]
    X_valid = X[X['scale'].isin([valid_time])]

    y_train = y[X['scale'].isin(train_times)]
    y_valid = y[X['scale'].isin([valid_time])]
    
    if SMAPE_ENABLED:
        y_train = to_percent(X_train, y_train)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)

    if SMAPE_ENABLED:
        y_pred = from_percent(X_valid, y_pred)
        
    X_valid['y_true'] = y_valid
    X_valid['y_base'] = X_valid['lags(1)']
    X_valid['y_pred'] = y_pred
    
    results.append(X_valid[['scale', 'month', 'state', 'county', 'cfips', 'y_true', 'y_base', 'y_pred']])
    
df_record = pd.concat(results, axis=0)
df_record.head()
# Out:
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
# [LightGBM] [Warning] lambda_l1 is set=1.8386216853616875, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.8386216853616875
# [LightGBM] [Warning] lambda_l2 is set=7.557660410418351, reg_lambda=0.0 will be ignored. Current value: lambda_l2=7.557660410418351
# [LightGBM] [Warning] min_data_in_leaf is set=213, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=213
# [LightGBM] [Warning] num_iterations is set=200, n_iter=200 will be ignored. Current value: num_iterations=200
#                  scale  month    state          county  cfips    y_true  \
# row_id
# 1001_2022-03-01     31      3  Alabama  Autauga County   1001  3.336785
# 1003_2022-03-01     31      3  Alabama  Baldwin County   1003  7.945311
# 1005_2022-03-01     31      3  Alabama  Barbour County   1005  1.196728
# 1007_2022-03-01     31      3  Alabama     Bibb County   1007  1.264755
# 1009_2022-03-01     31      3  Alabama   Blount County   1009  1.797986
#
#                    y_base    y_pred
# row_id
# 1001_2022-03-01  3.334431  3.337316
# 1003_2022-03-01  7.823300  7.832575
# 1005_2022-03-01  1.206827  1.207489
# 1007_2022-03-01  1.236650  1.237323
# 1009_2022-03-01  1.777708  1.779424

# %%
base_err = df_record.groupby('cfips').apply(lambda x: smape(x.y_true, x.y_base))
pred_err = df_record.groupby('cfips').apply(lambda x: smape(x.y_true, x.y_pred))

blacklist = base_err[(base_err + 1e-3) < pred_err].index

print(f'Avg SMAPE(model): {pred_err.mean():.3f}')
print(f'Avg SMAPE(base): {base_err.mean():.3f}')
print(len(blacklist))
# Out:
# Avg SMAPE(model): 1.409
# Avg SMAPE(base): 1.412
# 1694

# %%
idx = df_test[df_test['cfips'].isin(blacklist)].index

df_subm.loc[idx, target] = df_all.loc[idx, 'lags(1)']

# %%
df_subm[target] = df_subm[target].fillna(0)

# %%
df_subm.head()
# Out:
#                  microbusiness_density
# row_id
# 1001_2022-11-01               3.468241
# 1003_2022-11-01               8.375471
# 1005_2022-11-01               1.232074
# 1007_2022-11-01               1.287240
# 1009_2022-11-01               1.833519

# %%
df_subm.to_csv('submission.csv')
